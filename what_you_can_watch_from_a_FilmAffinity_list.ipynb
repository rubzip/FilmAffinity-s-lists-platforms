# %% [markdown]
# # FilmAffinity's lists
#
# FA does't show in what platform you can watch movies from a FA's list.
#
# I have made my own solution using webscrapping.
#
# ## VPNs and Platforms
#
# Platforms catalogue is different in every country, there are some movies that you can see in Netflix US but not in Netflix UK.
#
# I have automatized the way to search. The program gives you in what platforms you can watch the movies in four countries: Spain, US, UK and Canada (I'm limited by FilmAffinity). So if you have access to a VPN, you can watch more movies!
#
# # Listas de FilmAffinity
#
# En FilmAffinity no puedes saber de manera directa en qué plataforma se encuentran las peliculas de una lista.
#
# He implementado mediante webscrapping una solución a este problema.
#
# ## VPNs y plataformas
#
# Por motivos de distribuidoras y derechos, el catálogo de las plataformas es distinto en cada país, existen algunas películas que pueden verse en Netflix US pero no en Netflix España.
#
# Por esto he implementado una manera de automatizar la búsqueda. El programa te dice en qué plataformas puedes ver las películas de la lista en cuatro países: España, EEUU, Reino Unido y Canadá (el programa está limitado por FA). ¡Así que si tienes acceso a una VPN podrás ver muchas más peliculas!

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
from fun import *

# %%
#All acepted platforms:
all_platforms = [
 'Starz Play Amazon Channel',
 'Filmin Plus',
 'Movistar Plus',
 'Netflix',
 'Filmin',
 'fuboTV',
 'Rakuten TV',
 'HBO',
 'Microsoft Store',
 'Amazon Prime Video',
 'Spamflix',
 'Google Play Movies',
 'Amazon Video',
 'Apple iTunes',
 'HBO Max']
#All countries:
all_countries = [
 'es',
 'us',
 'uk',
 'ca',
]

# %%
#Only edit this cell:

#URL of the list:
URL = 'https://www.filmaffinity.com/es/userlist.php?user_id=9046485&list_id=1005'
#Number of pages of the list:
num_pages = 6
#Folder where CSVs are contained:
folder_name = './lists/'
#List name:
list_name = 'PELIS Q VER OBL'
#Name of the CSV generated with all movies in FA's list
CSV_file_name = list_name + '_list.csv'
#Name of the CSV generated with all movies in FA's list that you can watch
CSV_file_you_can_watch = list_name +  '_you_can_watch.csv'
#List of all platforms where you have an account:
your_plattforms = ['Amazon Prime Video', 'Filmin']
#Countries (VPN): 
countries = ['es']

# %%
list_name, movies = import_movies(URL, num_pages)
data = []
print('Importing info from internet...')
for movie in movies:
    name, rating, URL = movie_info(movie)
    print('\t', name)
    
    platforms_countries = []
    for country in countries:
        page = requests.get(URL[:29]+country+URL[31:])
        soup = BeautifulSoup(page.content, 'html')
        platfforms = rent_plattforms(soup, country)
        platforms_countries.append(platfforms)
    
    data.append([name, rating] + platforms_countries + [URL])
# Out:
# /home/ruben/Escritorio/FilmAffinity/fun.py:71: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 71 of the file /home/ruben/Escritorio/FilmAffinity/fun.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup
# 	 La lengua de las mariposas
# 	 Four Lions
# 	 Victoria
# 	 Moon
# 	 Mary and Max
# 	 La chica del gángster
# 	 La vida de Adèle
# 	 Así somos (People Like Us)
# 	 Castaway on the Moon
# 	 Annette
# 	 La cura del bienestar
# 	 La matanza de Texas
# 	 Submarine
# 	 Baskets (Serie de TV)
# 	 El graduado
# 	 Un funeral de muerte
# 	 Team America: La policía del mundo
# 	 Quemar después de leer
# 	 In the Loop
# 	 Sin City (Ciudad del pecado)
# 	 Extrañas coincidencias
# 	 El instante más oscuro
# 	 Drácula de Bram Stoker
# 	 Pleasure
# 	 El buen patrón
# 	 The Innocents
# 	 Historia de un matrimonio
# 	 Negociador
# 	 La reina de los lagartos
# 	 Punto de mira
# 	 Fahrenheit 451
# 	 Al final de la escapada
# 	 Pierrot el loco
# 	 El desprecio
# 	 Vivir su vida
# 	 Water Lillies
# 	 I Love You, Daddy
# 	 My Breakfast with Blassie
# 	 Mi cena con Hervé (TV)
# 	 El bar Coyote
# 	 November
# 	 Amor a quemarropa
# 	 La tumba de las luciérnagas (TV)
# 	 La tumba de las luciérnagas
# 	 La ruleta de la fortuna y la fantasía
# 	 La batalla de los sexos

# %%
#Name of the CSV generated with all movies in FA's list
CSV_file_name = folder_name + list_name + '_list.csv'
#Name of the CSV generated with all movies in FA's list that you can watch
CSV_file_you_can_watch = folder_name + list_name +  '_you_can_watch.csv'

# %%
df = generate_movies_df(data, countries)
df.to_csv(CSV_file_name)
df
# Out:
#                                          Name Rating   Platforms es  \
# 0                                    Stalker     7,9       [Filmin]
# 1                                   Triangle     6,4             []
# 2                                    Redline     6,9             []
# 3            La vida secreta de Walter Mitty     6,2             []
# 4    La Tierra errante (The Wandering Earth)     4,9      [Netflix]
# ..                                        ...    ...            ...
# 258                        Amor a quemarropa     7,3       [Filmin]
# 259          La tumba de las luciérnagas (TV)    7,7             []
# 260              La tumba de las luciérnagas     7,2             []
# 261    La ruleta de la fortuna y la fantasía     7,2             []
# 262                  La batalla de los sexos     6,0  [Disney Plus]
#
#                                                  URL
# 0    https://www.filmaffinity.com/es/film534365.html
# 1    https://www.filmaffinity.com/es/film675381.html
# 2    https://www.filmaffinity.com/es/film116352.html
# 3    https://www.filmaffinity.com/es/film758268.html
# 4    https://www.filmaffinity.com/es/film909718.html
# ..                                               ...
# 258  https://www.filmaffinity.com/es/film264296.html
# 259  https://www.filmaffinity.com/es/film489646.html
# 260  https://www.filmaffinity.com/es/film815855.html
# 261  https://www.filmaffinity.com/es/film645043.html
# 262  https://www.filmaffinity.com/es/film177537.html
#
# [263 rows x 4 columns]

# %%
df_you_can = what_you_can_watch(df, your_plattforms, countries)
df_you_can.to_csv(CSV_file_you_can_watch)
print('You can see from {} list all these movies: '.format(list_name))
df_you_can
# Out:
# You can see from Lista de Willy - PELIS Q VER OBLIGATORIAMENTE VAGO HIJO DE PUTA - FilmAffinity list all these movies:
#                   Name Rating                              Platforms es  \
# 0             Stalker     7,9                                  [Filmin]
# 1             Persona     8,2              [Amazon Prime Video, Filmin]
# 2            Psicosis     8,4                   [Movistar Plus, Filmin]
# 3          Despedidas     7,6              [Amazon Prime Video, Filmin]
# 4       El maquinista     7,1  [Amazon Prime Video, Filmin, Rakuten TV]
# ..                 ...    ...                                       ...
# 95      Punto de mira     5,8              [Amazon Prime Video, Filmin]
# 96     Fahrenheit 451     7,3                                  [Filmin]
# 97       El desprecio     7,4                                  [Filmin]
# 98      Vivir su vida     7,7                                  [Filmin]
# 99  Amor a quemarropa     7,3                                  [Filmin]
#
#                                                 URL
# 0   https://www.filmaffinity.com/es/film534365.html
# 1   https://www.filmaffinity.com/es/film878836.html
# 2   https://www.filmaffinity.com/es/film363992.html
# 3   https://www.filmaffinity.com/es/film892791.html
# 4   https://www.filmaffinity.com/es/film361537.html
# ..                                              ...
# 95  https://www.filmaffinity.com/es/film599679.html
# 96  https://www.filmaffinity.com/es/film714395.html
# 97  https://www.filmaffinity.com/es/film863642.html
# 98  https://www.filmaffinity.com/es/film693648.html
# 99  https://www.filmaffinity.com/es/film264296.html
#
# [100 rows x 4 columns]

# %%
df_you_can.sort_values(by="Rating", ascending=False)
# Out:
#                             Name Rating  \
# 22  El crepúsculo de los dioses     8,5
# 54                     El golpe     8,5
# 2                      Psicosis     8,4
# 51           Senderos de gloria     8,4
# 14                 Forrest Gump     8,2
# ..                           ...    ...
# 31            Todos a la cárcel     5,6
# 90        La cura del bienestar     5,6
# 26          7 días en La Habana     5,6
# 40                         Nine     5,1
# 94     La reina de los lagartos     5,1
#
#                                     Platforms es  \
# 22                       [Movistar Plus, Filmin]
# 54                       [Movistar Plus, Filmin]
# 2                        [Movistar Plus, Filmin]
# 51                                      [Filmin]
# 14                 [Amazon Prime Video, HBO Max]
# ..                                           ...
# 31  [Amazon Prime Video, Movistar Plus, FlixOlé]
# 90                          [Amazon Prime Video]
# 26                  [Amazon Prime Video, Filmin]
# 40                                      [Filmin]
# 94                                      [Filmin]
#
#                                                 URL
# 22  https://www.filmaffinity.com/es/film536488.html
# 54  https://www.filmaffinity.com/es/film385464.html
# 2   https://www.filmaffinity.com/es/film363992.html
# 51  https://www.filmaffinity.com/es/film448956.html
# 14  https://www.filmaffinity.com/es/film444796.html
# ..                                              ...
# 31  https://www.filmaffinity.com/es/film832849.html
# 90  https://www.filmaffinity.com/es/film454394.html
# 26  https://www.filmaffinity.com/es/film830558.html
# 40  https://www.filmaffinity.com/es/film472962.html
# 94  https://www.filmaffinity.com/es/film209715.html
#
# [100 rows x 4 columns]
